# %%
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from typing import TypedDict

# %%
load_dotenv()
model = ChatOpenAI()

# %%
class BlogState(TypedDict):
    title : str
    outline : str
    content : str

# %%
def create_outline(state : BlogState) -> BlogState:
    # fetch title
    title = state['title']

    prompt = f'Generate a detailed outline for a blog on the topic - {title}'
    outline = model.invoke(prompt).content

    state['outline'] = outline
    return state

# %%
def create_blog(state : BlogState) -> BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f'write a detailed blog on the title - {title} using the following outline \n {outline}'

    content = model.invoke(prompt).content
    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

# nodes
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

# edges

graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

# compile

workflow = graph.compile()

# %%
initial_state = {'title': 'Rise of AI in India'}

final_state = workflow.invoke(initial_state)

print(final_state)
# Out:
# {'title': 'Rise of AI in India', 'outline': 'I. Introduction\n    A. Define AI and its significance\n    B. Discuss the global rise of AI technology\n    C. Introduce the focus of the blog on the rise of AI in India\n\nII. Historical context of AI in India\n    A. Brief history of AI research and development in India\n    B. Key milestones and achievements in AI technology in India\n    C. Comparison with global AI development trends\n\nIII. Current state of AI in India\n    A. Overview of the AI industry in India\n    B. Key players and companies leading the AI revolution in India\n    C. Government initiatives and policies to support AI adoption\n    D. Challenges and barriers faced by the AI industry in India\n\nIV. AI applications in various sectors in India\n    A. Healthcare \n    B. Agriculture\n    C. Manufacturing\n    D. Finance\n    E. Retail \n    F. Transportation\n\nV. Role of academia in advancing AI in India\n    A. Research and innovation in AI at Indian universities and research institutions\n    B. Collaboration between academia and industry in the AI space\n    C. Talent development and skills training in AI\n\nVI. Future prospects of AI in India\n    A. Growth potential of the AI industry in India\n    B. Opportunities for AI startups and entrepreneurs\n    C. Potential impact of AI on the Indian economy and society\n    D. Ethical and regulatory considerations for AI development in India\n\nVII. Conclusion\n    A. Summarize key points discussed in the blog\n    B. Reflect on the future outlook for AI in India\n    C. Call to action for readers to stay informed and engaged in the development of AI in India.', 'content': 'The rise of Artificial Intelligence (AI) has been one of the most significant technological advancements in recent years, with its potential to revolutionize various industries and improve efficiency, productivity, and decision-making processes. While the global AI landscape has been rapidly evolving, the focus of this blog will be on the rise of AI in India, exploring the historical context, current state, applications in different sectors, the role of academia, future prospects, and the challenges and opportunities that lie ahead.\n\nI. Introduction\n\nA. AI can be defined as the simulation of human intelligence processes by machines, including learning, reasoning, problem-solving, perception, and decision-making. Its significance lies in its ability to automate tasks, analyze large data sets, and make predictions or recommendations based on patterns and trends.\n\nB. The global rise of AI technology has seen significant investments in research and development, leading to breakthroughs in areas such as machine learning, natural language processing, robotics, and computer vision.\n\nC. This blog will focus on the rise of AI in India, highlighting the growth of the AI industry, key players, government initiatives, applications in various sectors, the role of academia, and future prospects for AI technology in the country.\n\nII. Historical context of AI in India\n\nA. India has a rich history of AI research and development, dating back to the 1960s when the country established institutions like the Indian Statistical Institute and the Tata Institute of Fundamental Research to focus on AI and computer science.\n\nB. Key milestones in the development of AI technology in India include the creation of the Indian National AI Task Force in 1986, the launch of the National Supercomputing Mission in 2015, and the establishment of the National AI Portal in 2020.\n\nC. While India has made significant progress in AI research and development, there is still a gap compared to global trends, particularly in terms of funding, talent, and infrastructure.\n\nIII. Current state of AI in India\n\nA. The AI industry in India is growing rapidly, with startups, multinational corporations, and research institutions driving innovation and development in areas such as healthcare, agriculture, manufacturing, finan ...

# %%
print(final_state['outline'])
# Out:
# I. Introduction
#     A. Define AI and its significance
#     B. Discuss the global rise of AI technology
#     C. Introduce the focus of the blog on the rise of AI in India
#
# II. Historical context of AI in India
#     A. Brief history of AI research and development in India
#     B. Key milestones and achievements in AI technology in India
#     C. Comparison with global AI development trends
#
# III. Current state of AI in India
#     A. Overview of the AI industry in India
#     B. Key players and companies leading the AI revolution in India
#     C. Government initiatives and policies to support AI adoption
#     D. Challenges and barriers faced by the AI industry in India
#
# IV. AI applications in various sectors in India
#     A. Healthcare
#     B. Agriculture
#     C. Manufacturing
#     D. Finance
#     E. Retail
#     F. Transportation
#
# V. Role of academia in advancing AI in India
#     A. Research and innovation in AI at Indian universities and research institutions
#     B. Collaboration between academia and industry in the AI space
#     C. Talent development and skills training in AI
#
# VI. Future prospects of AI in India
#     A. Growth potential of the AI industry in India
#     B. Opportunities for AI startups and entrepreneurs
#     C. Potential impact of AI on the Indian economy and society
#     D. Ethical and regulatory considerations for AI development in India
#
# VII. Conclusion
#     A. Summarize key points discussed in the blog
#     B. Reflect on the future outlook for AI in India
#     C. Call to action for readers to stay informed and engaged in the development of AI in India.

# %%
print(final_state['content'])
# Out:
# The rise of Artificial Intelligence (AI) has been one of the most significant technological advancements in recent years, with its potential to revolutionize various industries and improve efficiency, productivity, and decision-making processes. While the global AI landscape has been rapidly evolving, the focus of this blog will be on the rise of AI in India, exploring the historical context, current state, applications in different sectors, the role of academia, future prospects, and the challenges and opportunities that lie ahead.
#
# I. Introduction
#
# A. AI can be defined as the simulation of human intelligence processes by machines, including learning, reasoning, problem-solving, perception, and decision-making. Its significance lies in its ability to automate tasks, analyze large data sets, and make predictions or recommendations based on patterns and trends.
#
# B. The global rise of AI technology has seen significant investments in research and development, leading to breakthroughs in areas such as machine learning, natural language processing, robotics, and computer vision.
#
# C. This blog will focus on the rise of AI in India, highlighting the growth of the AI industry, key players, government initiatives, applications in various sectors, the role of academia, and future prospects for AI technology in the country.
#
# II. Historical context of AI in India
#
# A. India has a rich history of AI research and development, dating back to the 1960s when the country established institutions like the Indian Statistical Institute and the Tata Institute of Fundamental Research to focus on AI and computer science.
#
# B. Key milestones in the development of AI technology in India include the creation of the Indian National AI Task Force in 1986, the launch of the National Supercomputing Mission in 2015, and the establishment of the National AI Portal in 2020.
#
# C. While India has made significant progress in AI research and development, there is still a gap compared to global trends, particularly in terms of funding, talent, and infrastructure.
#
# III. Current state of AI in India
#
# A. The AI industry in India is growing rapidly, with startups, multinational corporations, and research institutions driving innovation and development in areas such as healthcare, agriculture, manufacturing, finance, retail, and transportation.
#
# B. Key players leading the AI revolution in India include companies like Infosys, Wipro, Tata Consultancy Services, and startups like Zomato, Swiggy, and InMobi, which are leveraging AI technology to enhance their services and products.
#
# C. The Indian government has taken steps to support AI adoption through initiatives like the National AI Strategy, the AI Mission in Agriculture, and the setting up of AI research centers and labs.
#
# D. However, the AI industry in India faces challenges such as the lack of skilled talent, data privacy concerns, regulatory barriers, and ethical considerations related to AI development and deployment.
#
# IV. AI applications in various sectors in India
#
# A. In healthcare, AI technology is being used for medical imaging, diagnostics, personalized medicine, and drug discovery, improving patient care and treatment outcomes.
#
# B. In agriculture, AI solutions help farmers analyze soil and weather data, optimize crop yields, manage pests and diseases, and enhance agricultural productivity.
#
# C. In manufacturing, AI-powered robots and automation systems are transforming production processes, reducing costs, improving quality, and increasing efficiency.
#
# D. In finance, AI is being used for fraud detection, risk assessment, portfolio management, customer service, and algorithmic trading, enhancing the overall performance of financial institutions.
#
# E. In retail, AI technology enables personalized recommendations, inventory management, supply chain optimization, and customer engagement, leading to better shopping experiences and increased sales.
#
# F. In transportation, AI applications like self-driving cars, traffic management systems, predictive maintenance, and route optimization are revolutionizing the way people and goods are transported, making transportation safer, more efficient, and sustainable.
#
# V. Role of academia in advancing AI in India
#
# A. Indian universities and research institutions play a crucial role in advancing AI technology through research, innovation, and collaboration with industry partners.
#
# B. The collaboration between academia and industry in the AI space has led to the development of cutting-edge AI solutions, commercialization of research outcomes, and the creation of talent pipelines for the AI industry.
#
# C. To support the growing demand for AI skills, Indian universities offer programs in AI, machine learning, data science, and related fields, providing students with the knowledge and expertise needed to succeed in the AI industry.
#
# VI. Future prospects of AI in India
#
# A. The AI industry in India has significant growth potential, driven by factors such as increasing investments, government support, technological advancements, and the adoption of AI solutions across sectors.
#
# B. Opportunities for AI startups and entrepreneurs in India are abundant, with the availability of funding, mentorship, and a thriving ecosystem that encourages innovation, creativity, and collaboration.
#
# C. The potential impact of AI on the Indian economy and society is immense, with the technology expected to create new job opportunities, drive digital transformation, boost productivity, and improve the quality of services and products.
#
# D. However, ethical and regulatory considerations are crucial for the responsible development and deployment of AI technology in India, addressing issues related to bias, transparency, accountability, and data privacy.
#
# VII. Conclusion
#
# A. In conclusion, the rise of AI in India presents a wealth of opportunities for growth, innovation, and development in various sectors, while also posing challenges that need to be addressed through collaboration, research, and policy interventions.
#
# B. The future outlook for AI in India is promising, with the country poised to become a global hub for AI research, technology, and talent, contributing to economic growth, societal well-being, and technological advancement.
#
# C. As AI continues to evolve and transform the way we live, work, and interact with technology, it is essential for readers to stay informed, engaged, and proactive in shaping the development of AI in India, ensuring that it benefits society and contributes to a sustainable and inclusive future.
